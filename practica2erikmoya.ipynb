# %% [markdown]
# <a href="https://colab.research.google.com/github/kireayom16/classfiles/blob/main/practica2erikmoya.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
with open('/content/drive/MyDrive/classfiles/informe_acciones.txt', 'r', encoding='latin-1') as f:
        contenido = f.read()
# =captura el  nombre de la empresa y valor
informacion = re.findall( r"Te escribo para informarte sobre el valor actual de la acción de (.+?)\.\s*Fecha: .*?\s*Valor actual: \$([0-9.]+)",contenido)
for empresa, valor in informacion:
    print(f"📢 {empresa} → ${valor}")
# Out:
# 📢 Cisco Systems Inc. (CSCO) → $446.52
# 📢 Amazon.com Inc. (AMZN) → $520.22
# 📢 NVIDIA Corporation (NVDA) → $552.66
# 📢 Merck & Co., Inc. (MRK) → $722.88
# 📢 NVIDIA Corporation (NVDA) → $611.0
# 📢 Microsoft Corp. (MSFT) → $391.37
# 📢 The Home Depot Inc. (HD) → $1101.2
# 📢 Salesforce.com Inc. (CRM) → $242.94
# 📢 Exxon Mobil Corporation (XOM) → $1297.49
# 📢 MasterCard Inc. (MA) → $750.8
# 📢 Intel Corporation (INTC) → $1376.93
# 📢 MasterCard Inc. (MA) → $718.31
# 📢 Alphabet Inc. (GOOGL) → $1154.06
# 📢 AT&T Inc. (T) → $650.18
# 📢 Intel Corporation (INTC) → $969.01
# 📢 Microsoft Corp. (MSFT) → $1399.02
# 📢 Meta Platforms Inc. (META) → $1096.73
# 📢 Salesforce.com Inc. (CRM) → $786.31
# 📢 Netflix Inc. (NFLX) → $1497.06
# 📢 The Home Depot Inc. (HD) → $1303.97
# 📢 Alphabet Inc. (GOOGL) → $604.43
# 📢 Merck & Co., Inc. (MRK) → $1385.17
# 📢 Berkshire Hathaway Inc. (BRK.A) → $104.28
# 📢 Amazon.com Inc. (AMZN) → $871.25
# 📢 AT&T Inc. (T) → $1485.74
# 📢 Pfizer Inc. (PFE) → $553.89
# ...
